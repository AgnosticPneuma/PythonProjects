# %%
import pandas as pd
import numpy as np
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import datetime as dt

# %%
timeStamp=pd.Timestamp('2023-03-01')

# %%
period=pd.Period(timeStamp,freq='M')

# %%
period.asfreq('d')
# Out:
# Period('2023-03-31', 'D')

# %%
period+2
# Out:
# Period('2023-05', 'M')

# %%
index=pd.date_range(start='2020-1-1',periods=12,freq='ME')

# %%
data=np.random.random((12,1))
df=pd.DataFrame(data=data,index=index)

# %%
df
# Out:
#                    0
# 2020-01-31  0.701872
# 2020-02-29  0.969180
# 2020-03-31  0.646935
# 2020-04-30  0.174971
# 2020-05-31  0.778242
# 2020-06-30  0.141593
# 2020-07-31  0.055195
# 2020-08-31  0.133489
# 2020-09-30  0.478484
# 2020-10-31  0.441105
# 2020-11-30  0.742981
# 2020-12-31  0.237517

# %%
import yfinance as yf

# %%
stockprice=yf.download('GOOG',period='2y')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
stockprice_shifted=stockprice.Close.shift()

# %%
stockprice_shifted.head()
# Out:
# Date
# 2023-02-15          NaN
# 2023-02-16    97.099998
# 2023-02-17    95.779999
# 2023-02-21    94.589996
# 2023-02-22    92.050003
# Name: Close, dtype: float64

# %%
stockprice['change']=stockprice.Close.div(stockprice_shifted)

# %%
stockprice['return']=stockprice.change.sub(1).mul(100)

# %%
stockprice['Diff']=stockprice.Close.diff()

# %%
stockprice.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2023-02-15  94.739998  97.339996  94.360001  97.099998  96.752357  36964500
# 2023-02-16  95.540001  97.879997  94.970001  95.779999  95.437080  35642100
# 2023-02-17  95.070000  95.750000  93.449997  94.589996  94.251343  31095100
# 2023-02-21  93.239998  93.415001  92.000000  92.050003  91.720451  28367200
# 2023-02-22  91.933998  92.360001  90.870003  91.800003  91.471344  29891100
#
#               change    return      Diff
# Date
# 2023-02-15       NaN       NaN       NaN
# 2023-02-16  0.986406 -1.359423 -1.320000
# 2023-02-17  0.987576 -1.242433 -1.190002
# 2023-02-21  0.973147 -2.685266 -2.539993
# 2023-02-22  0.997284 -0.271592 -0.250000

# %%
stockprice['pct_change']=stockprice.Close.pct_change().mul(100)

# %%
stockprice
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-02-15   94.739998   97.339996   94.360001   97.099998   96.752357
# 2023-02-16   95.540001   97.879997   94.970001   95.779999   95.437080
# 2023-02-17   95.070000   95.750000   93.449997   94.589996   94.251343
# 2023-02-21   93.239998   93.415001   92.000000   92.050003   91.720451
# 2023-02-22   91.933998   92.360001   90.870003   91.800003   91.471344
# ...                ...         ...         ...         ...         ...
# 2025-02-10  189.059998  189.990005  187.610001  188.199997  188.199997
# 2025-02-11  186.835007  188.800003  186.080002  187.070007  187.070007
# 2025-02-12  185.229996  186.830002  183.630005  185.429993  185.429993
# 2025-02-13  185.929993  187.990005  184.880005  187.880005  187.880005
# 2025-02-14  186.830002  188.149994  186.110001  186.869995  186.869995
#
#               Volume    change    return      Diff  pct_change
# Date
# ...

# %%
stockprice['3d_ret']=stockprice.Close.pct_change(periods=30).mul(100)

# %%
stockprice
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-02-15   94.739998   97.339996   94.360001   97.099998   96.752357
# 2023-02-16   95.540001   97.879997   94.970001   95.779999   95.437080
# 2023-02-17   95.070000   95.750000   93.449997   94.589996   94.251343
# 2023-02-21   93.239998   93.415001   92.000000   92.050003   91.720451
# 2023-02-22   91.933998   92.360001   90.870003   91.800003   91.471344
# ...                ...         ...         ...         ...         ...
# 2025-02-10  189.059998  189.990005  187.610001  188.199997  188.199997
# 2025-02-11  186.835007  188.800003  186.080002  187.070007  187.070007
# 2025-02-12  185.229996  186.830002  183.630005  185.429993  185.429993
# 2025-02-13  185.929993  187.990005  184.880005  187.880005  187.880005
# 2025-02-14  186.830002  188.149994  186.110001  186.869995  186.869995
#
#               Volume    change    return      Diff  pct_change    3d_ret
# Date
# ...

# %%
google=yf.download('TCS.NS',period='1y')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['TCS.NS']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %%
stockprice=yf.download('GOOG',period='2y')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GOOG']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %%
import yfinance as yf
import pandas as pd

# %%
googlePrice=yf.download('TCS.NS',period='5y')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['TCS.NS']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
nifty=pd.read_csv('^NSEI.csv')

# %%
firstPrice=nifty.Close.iloc[0]

# %%
normalized=nifty.Close.div(firstPrice).mul(100)

# %%
normalized.plot()
# Out:
# <Axes: >
